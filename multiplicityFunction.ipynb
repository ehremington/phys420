# %% [markdown]
# ## import statements

# %%
# %matplotlib widget

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.special as sp

# %% [markdown]
# ## define some helpful functions

# %%
def factorial(x):
    return sp.factorial(x, exact=True)

def multiplicityEinstein(N,q):
    return factorial(q+N-1)//factorial(q)//factorial(N-1)

def logArray(array):
    import math as math
    return [math.log(x) for x in array]

# %% [markdown]
# ## Two Einstein Solids
# ### 3 particles each and 6 energy units

# %%
table1 = pd.DataFrame({'q_A':range(0, 6+1, 1),'q_B':range(6,0-1,-1)})
table1['multi_A'] = [multiplicityEinstein(3,i) for i in table1['q_A']]
table1['multi_B'] = [multiplicityEinstein(3,i) for i in table1['q_B']]
table1['multi_total'] = table1['multi_A']*table1['multi_B']

table1
# Out:
#    q_A  q_B  multi_A  multi_B  multi_total
# 0    0    6        1       28           28
# 1    1    5        3       21           63
# 2    2    4        6       15           90
# 3    3    3       10       10          100
# 4    4    2       15        6           90
# 5    5    1       21        3           63
# 6    6    0       28        1           28

# %% [markdown]
# #### how many total microstates from the above situation?
#
# First just add up the microstate from each macrostate

# %%
table1['multi_total'].sum()
# Out:
# 462

# %% [markdown]
# Alternatively, treat the two Einstein solids as one solid with the combined number of particles

# %%
multiplicityEinstein(6,6)
# Out:
# 462

# %% [markdown]
# #### most likely macrostate
# just sort the table for the macrostate with the highest total multiplicity.

# %%
table1.sort_values('multi_total', ascending=False).iloc[0]
# Out:
# q_A              3
# q_B              3
# multi_A         10
# multi_B         10
# multi_total    100
# Name: 3, dtype: int64

# %% [markdown]
# ## Now prepare a function to scale this up to large numbers

# %%
def multiTable(N_a, N_b, q):
    df = pd.DataFrame({'q_A':range(0, q+1, 1),'q_B':range(q, 0-1,-1)})
    df['multi_A'] = [multiplicityEinstein(N_a, i) for i in df['q_A']]
    df['multi_B'] = [multiplicityEinstein(N_b, i) for i in df['q_B']]
    df['multi_total'] = df['multi_A']*df['multi_B']
    return df

# %% [markdown]
# ### Try with Na = 300, Nb = 200, q = 100

# %%
table2 = multiTable(300, 200, 100)

# %%
fig0 = plt.figure()
ax0 = fig0.add_subplot(111)

ax0.bar(table2['q_A'], table2['multi_total'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <BarContainer object of 101 artists>

# %% [markdown]
# Make these numbers floats instead of integers so we can read them better. Note that this will break for numbers much larger than this.

# %%
table2 = table2.astype(float)

# %% [markdown]
# Total multiplicity of all macrostates:

# %%
total = table2['multi_total'].sum()
total
# Out:
# 9.261760158884879e+115

# %% [markdown]
# Total mulitplicity of all states as a combined Einstein solid.

# %%
float(multiplicityEinstein(500,100))
# Out:
# 9.261760158884879e+115

# %% [markdown]
# Most probable macrostate

# %%
table2.sort_values('multi_total', ascending=False).iloc[0]
# Out:
# q_A             6.000000e+01
# q_B             4.000000e+01
# multi_A         1.303375e+69
# multi_B         5.268097e+45
# multi_total    6.866305e+114
# Name: 60, dtype: float64

# %% [markdown]
# Multiplicity of the most common macrostate:

# %%
multi_max = table2['multi_total'].sort_values(ascending=False).iloc[0]
multi_max
# Out:
# 6.866305444480905e+114

# %% [markdown]
# ### Now to add in the Entropy

# %%
table2['S_a'] = logArray(table2['multi_A'])
table2['S_b'] = logArray(table2['multi_B'])
table2['S_total'] = logArray(table2['multi_total'])

# %%
table2
# Out:
#        q_A    q_B       multi_A       multi_B    multi_total         S_a  \
# 0      0.0  100.0  1.000000e+00  2.772168e+81   2.772168e+81    0.000000
# 1      1.0   99.0  3.000000e+02  9.271464e+80   2.781439e+83    5.703782
# 84    84.0   16.0  1.556187e+86  5.622825e+23  8.750169e+109  198.464557
# 85    85.0   15.0  7.030306e+86  4.184428e+22  2.941781e+109  199.972548
# 86    86.0   14.0  3.147288e+87  2.933010e+21  9.231027e+108  201.471444
# 87    87.0   13.0  1.396383e+88  1.927800e+20  2.691947e+108  202.961373
# 88    88.0   12.0  6.140911e+88  1.182141e+19  7.259426e+107  204.442461
# 89    89.0   11.0  2.677161e+89  6.723080e+17  1.799877e+107  205.914830
# 90    90.0   10.0  1.157129e+90  3.521613e+16  4.074959e+106  207.378600
# 91    91.0    9.0  4.959123e+90  1.684982e+15  8.356034e+105  208.833887
# 92    92.0    8.0  2.107627e+91  7.290789e+13  1.536627e+105  210.280806
# 93    93.0    7.0  8.883762e+91  2.817696e+12  2.503174e+104  211.719469
# 94    94.0    6.0  3.714169e+92  9.574696e+10  3.556203e+103  213.149983
# 95    95.0    5.0  1.540403e+93  2.802350e+09  4.316747e+102  214.572457
# 96    96.0    4.0  6.338115e+93  6.868505e+07  4.353337e+101  215.986995
# 97    97.0    3.0  2.587519e+94  1.353400e+06  3.501948e+100  217.393698
# 98    98.0    2.0  1.048209e+95  2.010000e+04   2.106901e+99  218.792667
# 99    99.0    1.0  4.214013e+95  2.000000e+02   8.428026e+97  220.183999
# 100  100.0    0.0  1.681391e+96  1.000000e+00   1.681391e+96  221.567790
#
#             S_b     S_total
# 0    187.529022  187.529022
# 1    186.433749  192.137531
# 2    185.331775  196.049521
# 3    184.223010  199.552571
# 4    183.107362  202.764361
# 5    181.984735  205.749323
# 6    180.855032  208.548173
# 7    179.718154  211.188970
# 8    178.574000  213.692222
# 9    177.422465  216.073562
# 10   176.263444  218.345297
# 11   175.096827  220.517357
# 12   173.922503  222.597919
# 13   172.740357  224.593828
# 14   171.550273  226.510890
# 15   170.352132  228.354091
# 16   169.145809  230.127752
# 17   167.931178  231.835650
# 18   166.708112  233.481114
# 19   165.476477  235.067091
# 20   164.236136  236.596209
# 21   162.986951  238.070823
# 22   161.728778  239.493048
# 23   160.461469  240.864797
# 24   159.184874  242.187800
# 25   157.898836  243.463630
# 26   156.603196  244.693718
# 27   155.297789  245.879372
# 28   153.982447  247.021785
# 29   152.656994  248.122050
# ..          ...         ...
# 71    84.334071  262.302308
# 72    82.272022  261.879794
# 73    80.179276  261.415483
# 74    78.054578  260.908298
# 75    75.896574  260.357062
# 76    73.703804  259.760484
# 77    71.474686  259.117150
# 78    69.207503  258.425503
# 79    66.900383  257.683829
# 80    64.551277  256.890234
# 81    62.157938  256.042617
# 82    59.717882  255.138641
# 83    57.228356  254.175695
# 84    54.686291  253.150848
# 85    52.088242  252.060790
# 86    49.430316  250.901760
# 87    46.708081  249.669455
# 88    43.916444  248.358906
# 89    41.049493  246.964323
# 90    38.100281  245.478881
# 91    35.060531  243.894419
# 92    31.920218  242.201024
# 93    28.666941  240.386409
# 94    25.284975  238.434958
# 95    21.753724  236.326182
# 96    18.045042  234.032037
# 97    14.118131  231.511829
# 98     9.908475  228.701142
# 99     5.298317  225.482317
# 100    0.000000  221.567790
#
# [101 rows x 8 columns]

# %% [markdown]
# #### Plotting Entropy

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)

ax1.plot(table2['q_A'], table2['S_a'], label='S_a')
ax1.plot(table2['q_A'], table2['S_b'], label='S_b')
ax1.plot(table2['q_A'], table2['S_total'], label='S_total')

# labels
ax1.set_ylabel('Entropy')
ax1.set_xlabel('q_A')

#legend
ax1.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
